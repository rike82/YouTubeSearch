# %%
api_key = "AIzaSyDBxkR-e2twCR1CnIJQ6zf8kocVX95MzgU"

# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from pprint import pprint

# %%
api_service_name = "youtube"
api_version = "v3"
    
    # Get credentials and create an API client   
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
category_ids = ['28', '22', '26', '27']

for category_id in category_ids:
    request = youtube.search().list(
        part="snippet",
        regionCode="US",
        type="video",
        maxResults=50,
         q=["health", "advice"],  
        videoCategoryId=category_id  # Eine einzelne Kategorie-ID übergeben
    )
    
    response_search = request.execute()
    pprint(response_search)
# Out:
# {'etag': 'VcDJMaWsQOBl8E169tXTtwdAN68',
#  'items': [{'etag': 'mFJNX2R8VbvdvN0f5rVLFzeG_9E',
#             'id': {'kind': 'youtube#video', 'videoId': '4ex9pUug8Vs'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCxyiSz4m161Z6frOsFxJpgw',
#                         'channelTitle': 'Cleveland Clinic',
#                         'description': "Guys: You'd do anything for your loved "
#                                        'ones. But what about you? When you '
#                                        "have a health concern, don't keep it "
#                                        'to yourself.',
#                         'liveBroadcastContent': 'none',
#                         'publishTime': '2019-08-30T16:49:20Z',
#                         'publishedAt': '2019-08-30T16:49:20Z',
#                         'thumbnails': {'default': {'height': 90,
# ...

# %%
################   placeholder for page token  ###########################

# %%
all_ids = []

for item in response['items']:
    all_ids.append(item['id']['videoId'])    
    
all_ids
# Out:
# ['TZ6Yz8MK_VA',
#  'vFWWuB7qi74',
#  'mUzq_h1GCXE',
#  'jCGk2n2zJ-s',
#  'dX_NqX_iyp4',
#  'xNoanoQ5syY',
#  '5bw99TXvGxg',
#  'Xp78EUBXI9E',
#  'enGv7955ELs',
#  'aRm0dh9TKbs',
#  'gwmv_KGdceA',
#  'rmx6kXSkujo',
#  'NQcYZplTXnQ',
#  'In72p1zRwIY',
#  'Y8HIFRPU6pM',
#  'vo5GBFFwyG4',
#  'UAjcINdnhig',
#  'Mf-JH_8f5CA',
#  'QPA3Y4th38g',
#  '-_VhU5rqyko',
#  'YNsuneGBsMY',
#  'E3QpXj_QOqQ',
#  '4lYY4ggfSJ4',
#  'MIc299Flibs',
#  'M0dod1IWo5Y',
#  'YJIxfta3Ppw',
#  'N19M1LtLXd8',
#  'FopfaWcDmqY',
#  'A9GOOaH7Ajc',
#  'jJMxKJ7GA20',
#  'b4HSu4MDzWQ',
#  'swSwq4O7X_M',
#  '-OAjfrhuwRk',
#  'CPo46Lgcc5s',
#  'i_LtB8XvNfc',
#  '_tdHVd5PiUs',
#  'oFWU7vk9fCw',
#  'AG6oRrv0z6s',
#  'HXODwBl89TU',
#  'kVOjq9yCQ-k',
#  'CfKxDx8MAYE',
#  'l2dMwJ1OAQI',
#  'c0juk-7qn0Y',
#  'TdvjU37mXHY',
#  'S9oGLqNiQtI',
#  'btjMjR114z8',
#  '8jDeIEMgRqk',
#  'Rul4IYmr5xs',
#  'PwZK8e-KaUU',
#  'PP5JX-0ab4c']

# %%
request = youtube.videos().list(
    part="snippet,contentDetails,statistics",        
    id = all_ids
)

response_video = request.execute()

#response_video

# %%
# Loop to retrieve required values
# item lists

channel_title_list = []
title_list = []
published_at_list = []
tags_list = []
like_count_list = []
view_count_list = []
comment_count_list = []

for item in response_video['items']:
    # Extracting items out of JSON
    
    channel_title = item['snippet']['channelTitle']
    title = item['snippet']['title']
    published_at = item['snippet']['publishedAt']
    tags = item['snippet'].get('tags', [])  # Use .get to handle missing tags
   
    # Appending the items into lists
    
    channel_title_list.append(channel_title)
    title_list.append(title)
    published_at_list.append(published_at)
    tags_list.append(tags)
    
    # Extracting statistics
    statistics = item.get('statistics', {})
    like_count = statistics.get('likeCount', 'N/A')
    view_count = statistics.get('viewCount', 'N/A')
    comment_count = statistics.get('commentCount', 'N/A')
    favorite_count = statistics.get('favoriteCount', 'N/A')
    
    # Appending statistics into lists
    like_count_list.append(like_count)
    view_count_list.append(view_count)
    comment_count_list.append(comment_count)
    # Print the retrieved values
    
    print(f"Channel Title: {channel_title}")
    print(f"Title: {title}")
    print(f"Published At: {published_at}") # it's still a string and has to be converted into a datetime
    print(f"Tags: {', '.join(tags)}")
    print(f"Like Count: {like_count}")
    print(f"View Count: {view_count}")
    print(f"Comment Count: {comment_count}")
    print(f"Favorite Count: {favorite_count}\n")

print(len(channel_title_list))
print(len(title_list))
print(len(published_at_list))
print(len(tags_list))
print(len(like_count_list))
print(len(view_count_list))
print(len(comment_count_list))
# Out:
# Channel Title: Doctor Mike
# Title: Fact Checking 100-Year-Old’s Health Advice
# Published At: 2024-02-14T17:00:17Z
# Tags: doctor mike, dr mike, drmike, dr. mike, mikhail varshavski, doctor mikhail varshavski, mike varshavski, doctor reacts, old people, old folks, seniors, 100 year olds, centagenarians, centagenarian, old people advice, dr. pepper lady, nursing home, veteran, old people health hacks, health advice for seniors
# Like Count: 57559
# View Count: 2009065
# Comment Count: 1987
# Favorite Count: 0
#
# Channel Title: Dr. John Campbell
# Title: Florida advises against mRNA
# Published At: 2024-09-14T10:49:38Z
# Tags: physiology, nursing, NCLEX, health, disease, biology, medicine, nurse education, medical education, pathophysiology, campbell, human biology, human body
# Like Count: 33549
# View Count: 360590
# Comment Count: 4571
# Favorite Count: 0
#
# Channel Title: Doctor Mike
# Title: One Health Hack From Every Type Of Doctor
# Published At: 2023-04-19T15:17:12Z
# ...

# %%
data = {
    'Published At': published_at_list,
    'Channel Title': channel_title_list,
    'Title': title_list,
    'Tags': tags_list,
    'Like Count': like_count_list,
    'View Count': view_count_list,
    'Comment Count': comment_count_list
}
# Create a DataFrame
df = pd.DataFrame(data)
# Sort the DataFrame by the "Published At" column in ascending order
df = df.sort_values(by='Published At', ascending=True)
# Display the sorted DataFrame
df
# Display the DataFrame
# Out:
#             Published At                                    Channel Title  \
# 47  2012-03-19T12:18:29Z                            Vanderbilt University
# 33  2013-03-26T19:00:37Z                       American Heart Association
# 45  2016-04-27T16:23:04Z                                            NHLBI
# 9   2017-02-28T20:50:15Z                                Healthcare Triage
# 41  2017-11-27T02:18:42Z                                 The Dr. Bob Show
# 3   2017-12-08T12:59:19Z                                     DocMikeEvans
# 14  2018-04-23T14:00:02Z                                 Health Chronicle
# 32  2018-07-30T06:08:23Z                                      SafeWork SA
# 25  2018-09-23T12:00:07Z                                 Dr. Eric Berg DC
# 42  2018-10-19T18:00:02Z                                Dr. Nick Zyrowski
# 10  2018-10-30T12:13:00Z                                 Doctor Ali Mattu
# 30  2019-02-05T20:13:06Z                                Michigan Medicine
# ...

# %%
 ## neue spalte covid corona health in tags ###

# %%
df.isna().any()
# Out:
# Published At     False
# Channel Title    False
# Title            False
# Tags             False
# Like Count       False
# View Count       False
# Comment Count    False
# dtype: bool

# %%
df.duplicated().any()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df.duplicated().any()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6253, in DataFrame.duplicated(self, subset, keep)
#    6250     raise KeyError(diff)
#    6252 vals = (col.values for name, col in self.items() if name in subset)
# -> 6253 labels, shape = map(list, zip(*map(f, vals)))
#    6255 ids = get_group_index(
#    6256     labels,
#    6257     # error: Argument 1 to "tuple" has incompatible type "List[_T]";
#    (...)
#    6261     xnull=False,
#    6262 )
#    6263 result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6226, in DataFrame.duplicated.<locals>.f(vals)
#    6225 def f(vals) -> tuple[np.ndarray, int]:
# ...
